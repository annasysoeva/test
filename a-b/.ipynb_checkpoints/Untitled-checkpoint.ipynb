# %%
import pandas as pd

# %%
data = pd.read_csv('Netology_A_B-testing_HW_1.csv')

# %% [markdown]
# Date - дата сессии
# User_id - id пользователя
# Hour - час старта сессии
# App_opened - приложение открыто
# Price_seen - пользователь ввел данные маршрута и показана цена
# Order_made - пользователь кликнул по кнопке заказа
# Surge - в этот период был включен surge (надбавка к стоимости поездки в период повышенного спроса)
# Ride_completed - поездка успешно завершена
# User_cancelled - пользователь отменил поездку
# Age - возраст пользователя
# Os - операционная система на телефоне
# City_center_order - заказ был сделан из центра города
# Order_class - класс поездки
# Distance - дистанция в км
# Rfm - rfm-сегментпользователя

# %%
data
# Out:
#         Unnamed: 0        date  user_id  hour  app_opened  price_seen  \
# 0                0  2020-05-21   867689    12           1           1
# 1                1  2020-05-23   752172     5           1           1
# 2                2  2020-05-20   486559    15           1           1
# 3                3  2020-05-19   304024     0           1           1
# 4                4  2020-05-23   139420     0           1           1
# ...            ...         ...      ...   ...         ...         ...
# 101495      101495  2020-05-24   288445    16           1           1
# 101496      101496  2020-05-19   627754     2           1           1
# 101497      101497  2020-05-23   784442     1           1           1
# 101498      101498  2020-05-20   232993    13           1           1
# 101499      101499  2020-05-22   337225    21           1           1
#
#         order_made     surge  ride_completed  user_cancelled  age       os  \
# ...

# %%
for col in data.columns:
    pct_missing = data[col].isna().mean()
    print(f'{col} - {pct_missing :.1%}')
    
# поиск стобцов с пропусками
# Out:
# Unnamed: 0 - 0.0%
# date - 0.0%
# user_id - 0.0%
# hour - 0.0%
# app_opened - 0.0%
# price_seen - 0.0%
# order_made - 0.0%
# surge - 9.9%
# ride_completed - 0.0%
# user_cancelled - 0.0%
# age - 0.0%
# os - 0.0%
# city_center_order - 0.0%
# order_class - 0.0%
# distance - 9.9%
# rfm - 0.0%

# %% [markdown]
# # No.1

# %%
with_ = data.loc[data['surge'] == 'surge'] # with surge
without = data.loc[data['surge'] == 'no surge'] # without surge

# %%
with_.count().head(1)
# Out:
# Unnamed: 0    31643
# dtype: int64

# %%
without.count().head(1)
# Out:
# Unnamed: 0    59788
# dtype: int64

# %% [markdown]
# # No.2

# %%
seen = data.loc[data['price_seen'] == 1] # показана цена при заказе
not_seen = data.loc[data['price_seen'] == 0] # не показана цена при заказе

# %%
seen['user_cancelled'].count()
# Out:
# 91431

# %%
not_seen['user_cancelled'].count()
# Out:
# 10069

# %% [markdown]
# # No.3

# %%
business = data.loc[data['order_class'] == 'business'] # показана цена при заказе
comfort = data.loc[data['order_class'] == 'comfort'] # не показана цена при заказе 
economy = data.loc[data['order_class'] == 'economy']

# %%
business['user_cancelled'].count()
# Out:
# 12033

# %%
comfort['user_cancelled'].count()
# Out:
# 42248

# %%
economy['user_cancelled'].count()
# Out:
# 47219

# %% [markdown]
# # No.4

# %%
data.groupby(['os']).count()
# Out:
#          Unnamed: 0   date  user_id   hour  app_opened  price_seen  \
# os
# Android       56696  56696    56696  56696       56696       56696
# iOS           44804  44804    44804  44804       44804       44804
#
#          order_made  surge  ride_completed  user_cancelled    age  \
# os
# Android       56696  50049           56696           56696  56696
# iOS           44804  41382           44804           44804  44804
#
#          city_center_order  order_class  distance    rfm
# os
# Android              56696        56696     50049  56696
# iOS                  44804        44804     41382  44804

# %% [markdown]
# # No.5

# %%
data['app_opened'].count()
# Out:
# 101500

# %%
data.loc[data['order_made'] == 1].count()
# Out:
# Unnamed: 0           74236
# date                 74236
# user_id              74236
# hour                 74236
# app_opened           74236
# price_seen           74236
# order_made           74236
# surge                74236
# ride_completed       74236
# user_cancelled       74236
# age                  74236
# os                   74236
# city_center_order    74236
# order_class          74236
# distance             74236
# rfm                  74236
# dtype: int64

# %% [markdown]
# # No.6

# %%
data.groupby(['rfm']).count()
# Out:
#         Unnamed: 0   date  user_id   hour  app_opened  price_seen  order_made  \
# rfm
# high         12163  12163    12163  12163       12163       12163       12163
# low          47364  47364    47364  47364       47364       47364       47364
# medium       41973  41973    41973  41973       41973       41973       41973
#
#         surge  ride_completed  user_cancelled    age     os  \
# rfm
# high    10891           12163           12163  12163  12163
# low     42760           47364           47364  47364  47364
# medium  37780           41973           41973  41973  41973
#
#         city_center_order  order_class  distance
# rfm
# high                12163        12163     10891
# low                 47364        47364     42760
# medium              41973        41973     37780
