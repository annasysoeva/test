# %% [markdown]
# # Задание 1

# %%
import requests

# %%
def get_currency():
    r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
    lst = []
    
    for i, k in r.json()['Valute'].items():
        lst.append(k['Name'])
        lst.append(k['Value'])
        
    sort = tuple(lst)
    
    print(sort)

get_currency()
# Out:
# ('Австралийский доллар', 57.0559, 'Азербайджанский манат', 43.1368, 'Фунт стерлингов Соединенного королевства', 102.0703, 'Армянских драмов', 13.9705, 'Белорусский рубль', 28.3958, 'Болгарский лев', 45.4988, 'Бразильский реал', 13.6477, 'Венгерских форинтов', 24.9136, 'Гонконгских долларов', 94.5342, 'Датская крона', 11.9672, 'Доллар США', 73.2895, 'Евро', 88.9441, 'Индийских рупий', 10.0697, 'Казахстанских тенге', 17.5885, 'Канадский доллар', 57.973, 'Киргизских сомов', 86.7415, 'Китайский юань', 11.3483, 'Молдавских леев', 42.2601, 'Норвежских крон', 87.513, 'Польский злотый', 19.8332, 'Румынский лей', 18.2544, 'СДР (специальные права заимствования)', 105.5918, 'Сингапурский доллар', 55.3672, 'Таджикских сомони', 64.3172, 'Турецкая лира', 10.5729, 'Новый туркменский манат', 20.9698, 'Узбекских сумов', 69.534, 'Украинских гривен', 26.3253, 'Чешских крон', 34.6432, 'Шведских крон', 88.5866, 'Швейцарский франк', 82.4311, 'Южноафриканских рэндов', 50.6654, 'Вон Республики Корея', 66.4938, 'Японских иен', 69.4687)

# %% [markdown]
# # Задание 2

# %%
class Rate:
    def __init__(self, format_='value', diff = True):
        self.format = format_
        self.diff = diff
    
    def exchange_rates(self):
        """
        Возвращает ответ сервиса с информацией о валютах в виде:
        
        {
            'AMD': {
                'CharCode': 'AMD',
                'ID': 'R01060',
                'Name': 'Армянских драмов',
                'Nominal': 100,
                'NumCode': '051',
                'Previous': 14.103,
                'Value': 14.0879
                },
            ...
        }
        """
        self.r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
        return self.r.json()['Valute']
    
    def make_format(self, currency, diff):
        """
        Возвращает информацию о валюте currency в двух вариантах:
        - полная информация о валюте при self.format = 'full':
        Rate('full').make_format('EUR')
        {
            'CharCode': 'EUR',
            'ID': 'R01239',
            'Name': 'Евро',
            'Nominal': 1,
            'NumCode': '978',
            'Previous': 79.6765,
            'Value': 79.4966
        }
        
        Rate('value').make_format('EUR')
        79.4966
        """
        response = self.exchange_rates()
        if diff == True:
            prev = response[currency]['Previous']
            now = response[currency]['Value']
            differ = now - prev
            return differ
       
        
        if currency in response:
            if self.format == 'full':
                return response[currency]
            
            if self.format == 'value':
                return response[currency]['Value']
            
        
            
        
        return 'Error'
    
    def eur(self, diff):
        """Возвращает курс евро на сегодня в формате self.format"""
        return self.make_format('EUR')
        if diff == True:
            print('num')
    
    def usd(self):
        """Возвращает курс доллара на сегодня в формате self.format"""
        return self.make_format('USD')
    
    def brl(self):
        """Возвращает курс бразильского реала на сегодня в формате self.format"""
        return self.make_format('BRL')

# %%
Rate().make_format('USD', diff = False)
# Out:
# 73.2895

# %% [markdown]
# # Задание 3

# %%
class Employee:
    def __init__(self, name, seniority):
        self.name = name
        self.seniority = seniority
        
        self.grade = 1
    
    def grade_up(self):
        """Повышает уровень сотрудника"""
        self.grade += 1
    
    def publish_grade(self):
        """Публикация результатов аккредитации сотрудников"""
        print(self.name, self.grade)
    
    def check_if_it_is_time_for_upgrade(self):
        pass

# %%
class Designer(Employee):
    def __init__(self, name, seniority, award):
        self.name = name
        self.seniority = seniority
        self.award = award
        
        self.grade = 1
    
    def grade_up(self):
        self.grade += 1
    
    def publish_grade(self):
        print(self.name, self.grade)
        
    def check_if_it_is_time_for_upgrade(self):
        award = 2
        
        self.seniority += award * 2 + 1
        
        if self.seniority % 7 == 0:
            self.grade_up()
            
        return self.publish_grade()
