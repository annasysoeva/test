# %%
class emp:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        
    def up(self):
        self.salary += 100
        
    def printt(self):
        print('Сотрудник', self.name, ', зарплата', self.salary)

# %%
ivan = emp(name = 'Иван', salary = 100)

# %%
ivan.printt()
ivan.up()
ivan.printt()
# Out:
# Сотрудник Иван , зарплата 1200
# Сотрудник Иван , зарплата 1300

# %% [markdown]
# ***

# %%
import requests

# %%
def get_currency():
    r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
    lst = []
    
    for i, k in r.json()['Valute'].items():
        lst.append(k['Name'])
        lst.append(k['Value'])
        
    sort = tuple(lst)
    
    print(sort)

get_currency()
# Out:
# ('Австралийский доллар', 57.0639, 'Азербайджанский манат', 43.1484, 'Фунт стерлингов Соединенного королевства', 101.9218, 'Армянских драмов', 13.989, 'Белорусский рубль', 28.4398, 'Болгарский лев', 45.4913, 'Бразильский реал', 13.6514, 'Венгерских форинтов', 24.8102, 'Гонконгских долларов', 94.5571, 'Датская крона', 11.9644, 'Доллар США', 73.3092, 'Евро', 88.9754, 'Индийских рупий', 10.097, 'Казахстанских тенге', 17.5806, 'Канадский доллар', 57.8879, 'Киргизских сомов', 86.7179, 'Китайский юань', 11.3513, 'Молдавских леев', 42.156, 'Норвежских крон', 87.1121, 'Польский злотый', 19.8042, 'Румынский лей', 18.2529, 'СДР (специальные права заимствования)', 105.6202, 'Сингапурский доллар', 55.4281, 'Таджикских сомони', 64.3345, 'Турецкая лира', 10.5101, 'Новый туркменский манат', 20.9755, 'Узбекских сумов', 69.5335, 'Украинских гривен', 26.1655, 'Чешских крон', 34.5326, 'Шведских крон', 88.6051, 'Швейцарский франк', 82.2682, 'Южноафриканских рэндов', 50.7527, 'Вон Республики Корея', 66.5319, 'Японских иен', 69.6756)

# %% [markdown]
# ***

# %%
class Rate:
    def __init__(self, format_='value', diff = True):
        self.format = format_
        self.diff = diff
    
    def exchange_rates(self):
        """
        Возвращает ответ сервиса с информацией о валютах в виде:
        
        {
            'AMD': {
                'CharCode': 'AMD',
                'ID': 'R01060',
                'Name': 'Армянских драмов',
                'Nominal': 100,
                'NumCode': '051',
                'Previous': 14.103,
                'Value': 14.0879
                },
            ...
        }
        """
        self.r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
        return self.r.json()['Valute']
    
    def make_format(self, currency, diff):
        """
        Возвращает информацию о валюте currency в двух вариантах:
        - полная информация о валюте при self.format = 'full':
        Rate('full').make_format('EUR')
        {
            'CharCode': 'EUR',
            'ID': 'R01239',
            'Name': 'Евро',
            'Nominal': 1,
            'NumCode': '978',
            'Previous': 79.6765,
            'Value': 79.4966
        }
        
        Rate('value').make_format('EUR')
        79.4966
        """
        response = self.exchange_rates()
        if diff == True:
            prev = response[currency]['Previous']
            now = response[currency]['Value']
            differ = now - prev
            return differ
       
        
        if currency in response:
            if self.format == 'full':
                return response[currency]
            
            if self.format == 'value':
                return response[currency]['Value']
            
        
            
        
        return 'Error'
    
    def eur(self, diff):
        """Возвращает курс евро на сегодня в формате self.format"""
        return self.make_format('EUR')
        if diff == True:
            print('num')
    
    def usd(self):
        """Возвращает курс доллара на сегодня в формате self.format"""
        return self.make_format('USD')
    
    def brl(self):
        """Возвращает курс бразильского реала на сегодня в формате self.format"""
        return self.make_format('BRL')

# %%
Rate().make_format('USD', diff = False)
# Out:
# 73.3092
