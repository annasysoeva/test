# %%
print (1 + 1)
# Out:
# 2

# %%
1 + 1 # you don't have to use print if there is only one result
# Out:
# 2

# %%
len ("abc") > len("abcf")
# Out:
# False

# %%
a = 10 + 20

# %%
a
# Out:
# 30

# %%
print ("He said 'Hello'")
# Out:
# He said 'Hello'

# %%
my_string_1 = 'He said "Hello"''

# %%
my_string_1
# Out:
# 'He said "Hello"'

# %%
7 == 7
# Out:
# True

# %%
15 != 15
# Out:
# False

# %%
height = 210
if height < 180:
    print ("в танкисты")
elif height < 200:
    print ("в десантники")
else: 
    print ("в другие войска")
# Out:
# в другие войска

# %%
height = 180

# %%
age = 20
if age >= 18:
    user_input = int(input('Введите рост'))
    if user_input < 170:
        print ('В танкисты')
    elif user_input < 185:
        print ('Во флот')
    elif user_input < 200:
        print ('В десантники')
    else:
        print ('В другие войска')
else:
    print ('Непризывной возраст')
print ('Конец программы')
# Out:
# Введите рост210
# В другие войска
# Конец программы

# %%
my_string = 'I am learning Python'

# %%
my_string [:13]
# Out:
# 'I am learning'

# %%
target_string = 'SQL'

if target_string in my_string:
    print ('found')
else:
    print ('not found')
# Out:
# not found

# %%
name = 'anna'
lang = 'python'

print (f"Hello, {name}, i know {lang.capitalize ()} a bit")
# Out:
# Hello, anna, i know Python a bit

# %%
month_list = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Jan']
income_list = [13000, 14000, 14300, 15000, 13800, 13000, 14900, 15200, 15300]
income_by_months = [['Jan', 13000], ['Feb', 14000], ['Mar', 14300], ['Apr', 15000], ['May', 13800], ['Jun', 13000], ['Jul', 14900], ['Aug', 13000], ['Sep', 14000], ['Oct', 14300], ['Nov', 15000], ['Jan', 13800]]

# %%
income_by_months [1] [1]
# Out:
# 15000

# %%
income_by_months_2 = [['Nov', 15], ['Dec', 16]]
income_by_months = income_by_months + income_by_months_2

# %%
print (income_by_months)
# Out:
# [['Jan', 13000], ['Feb', 14000], ['Mar', 14300], ['Apr', 15000], ['May', 13800], ['Jun', 13000], ['Jul', 14900], ['Aug', 13000], ['Sep', 14000], ['Oct', 14300], ['Nov', 15000], ['Jan', 13800], ['Nov', 15], ['Dec', 16]]

# %%
first, second, third = ['первый', 'второй', 'третий']
third
# Out:
# 'третий'

# %%
income_by_months.remove ['Jan', 13800]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-6058ff1b8c1a> in <module>
# ----> 1 income_by_months.remove ['Jan', 13800]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
income_by_months
# Out:
# [['Jan', 13000],
#  ['Feb', 14000],
#  ['Mar', 14300],
#  ['Apr', 15000],
#  ['May', 13800],
#  ['Jun', 13000],
#  ['Jul', 14900],
#  ['Aug', 13000],
#  ['Sep', 14000],
#  ['Oct', 14300],
#  ['Nov', 15000],
#  ['Jan', 13800]]

# %%
import copy

# %%
a = [1, 2, 3]
b = copy.copy (a)

# %%
b.append (4)

# %%
a
# Out:
# [1, 2, 3]

# %%
salary_tuple = (1000, 1200, 1300, 900, 800)

# %%
salary_tuple
# Out:
# (1000, 1200, 1300, 900, 800)

# %%
t = ('one', )

# %%
type(t)
# Out:
# tuple

# %%
f = ('one')

# %% [markdown]
# # Цикл while

# %%
x = 5
while x != 0:
    x -= 1
    print (x)
