# %%
f = open('visit_log.csv', 'r')

# %%
f.readline()
# Out:
# 'user_id,source\n'

# %%
another_line = f.readline()
print(another_line)
# Out:
# 71bcf169b4,other

# %%
another_line.strip().split(',')
# Out:
# ['71bcf169b4', 'other']

# %%
with open('visit_log.csv', 'r') as f:
    with open('email_log.csv', 'w') as f2write:
        for line in f:
            if 'email' in line:
                f2write.write(line)

# %%
f2 = open('email_log.csv', 'r')

# %%
f2.readline()
# Out:
# 'b18d58560b,email\n'

# %%
import json

# %%
i = 0
with open('purchase_log.txt') as f:
    for line in f:
        line = line.strip()
        
        dict_ = json.loads(line)
        print(dict_, type(dict_))
        
        i += 1
        if i > 5:
            break

# %%
i = 0

with open('purchase_log.txt') as a:
    for line in a:
        line = line.strip()
        
        dict_ = json.loads(line)
        print(dict_)
        
        i += 1
        if i > 2:
            break
# Out:
# {'user_id': 'user_id', 'category': 'category'}
# {'user_id': '1840e0b9d4', 'category': 'РџСЂРѕРґСѓРєС‚С‹'}
# {'user_id': '4e4f90fcfb', 'category': 'Р\xadР»РµРєС‚СЂРѕРЅРёРєР°'}
